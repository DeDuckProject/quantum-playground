# %%
! pip install pylatexenc
! pip install qiskit
# Out:
# Requirement already satisfied: pylatexenc in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (2.10)
# Requirement already satisfied: qiskit in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (0.31.0)
# Requirement already satisfied: qiskit-ignis==0.6.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.6.0)
# Requirement already satisfied: qiskit-aqua==0.9.5 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.9.5)
# Requirement already satisfied: qiskit-ibmq-provider==0.17.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.17.0)
# Requirement already satisfied: qiskit-terra==0.18.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.18.3)
# Requirement already satisfied: qiskit-aer==0.9.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.9.1)
# Requirement already satisfied: numpy>=1.16.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.20.1)
# Requirement already satisfied: scipy>=1.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.6.2)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (52.0.0.post20210125)
# Requirement already satisfied: sympy>=1.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.8)
# Requirement already satisfied: dlx<=1.0.4 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.0.4)
# Requirement already satisfied: fastdtw<=0.3.4 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.3.4)
# Requirement already satisfied: quandl in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (3.6.1)
# Requirement already satisfied: pandas in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.2.4)
# Requirement already satisfied: docplex>=2.21.207 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (2.22.213)
# Requirement already satisfied: h5py<3.3.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (2.10.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.24.1)
# Requirement already satisfied: yfinance>=0.1.62 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.1.64)
# Requirement already satisfied: retworkx>=0.8.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.10.2)
# Requirement already satisfied: psutil>=5 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (5.8.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.17.0->qiskit) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.17.0->qiskit) (1.26.4)
# Requirement already satisfied: websocket-client>=1.0.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.17.0->qiskit) (1.2.1)
# Requirement already satisfied: requests>=2.19 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.17.0->qiskit) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.17.0->qiskit) (2.8.1)
# Requirement already satisfied: dill>=0.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (0.3.4)
# Requirement already satisfied: fastjsonschema>=2.10 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.2.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (1.1.1)
# Requirement already satisfied: python-constraint>=1.4 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (1.4.0)
# Requirement already satisfied: symengine>0.7 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (0.8.1)
# Requirement already satisfied: ply>=3.10 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.11)
# Requirement already satisfied: six in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from docplex>=2.21.207->qiskit-aqua==0.9.5->qiskit) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (20.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.17.0->qiskit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.17.0->qiskit) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.17.0->qiskit) (4.0.0)
# Requirement already satisfied: cryptography>=1.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.17.0->qiskit) (3.4.7)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.17.0->qiskit) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.17.0->qiskit) (1.14.5)
# Requirement already satisfied: pycparser in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.17.0->qiskit) (2.20)
# Requirement already satisfied: joblib>=0.11 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (2.1.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from sympy>=1.3->qiskit-aqua==0.9.5->qiskit) (1.2.1)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from pandas->qiskit-aqua==0.9.5->qiskit) (2021.1)
# Requirement already satisfied: more-itertools in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (8.7.0)
# Requirement already satisfied: inflection>=0.3.1 in /Users/yiftachy/opt/anaconda3/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (0.5.1)

# %%
# initialization
import numpy as np
from numpy import pi

# importing Qiskit
from qiskit import IBMQ, Aer
from qiskit.providers.ibmq import least_busy
from qiskit import QuantumCircuit, assemble, transpile
# from ibm_quantum_widgets import CircuitComposer
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.tools.visualization import circuit_drawer

# import basic plot tools
from qiskit.visualization import plot_histogram

from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

# %%
# circuit 1
n = 1
qreg_q = QuantumRegister(n, 'q')
creg_c = ClassicalRegister(n, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(0)
circuit.measure(0,0)

circuit.draw('mpl')

# %%
# circuit 2
n = 1
qreg_q = QuantumRegister(n, 'q')
creg_c = ClassicalRegister(n, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(0)
circuit.h(0)
circuit.measure(0,0)

circuit.draw('mpl')

# %%
# circuit 3
n = 2
qreg_q = QuantumRegister(n, 'q')
creg_c = ClassicalRegister(n, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(0)
circuit.measure(0,0)
circuit.h(0)
circuit.measure(0,1)

circuit.draw('mpl')

# %%
# Print state vector - NOTE: this computes only for circuits w/o a measurement.

# Set the intial state of the simulator to the ground state using from_int
state = Statevector.from_int(0, 2**n)

# # Evolve the state by the quantum circuit
state = state.evolve(circuit)

# #draw using latex
state.draw('latex')
# Out:
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
# %matplotlib inline

state = Statevector.from_instruction(circuit)
plot_bloch_multivector(state, title="Bloch Sphere", reverse_bits=False)

# %%
# use local simulator
aer_sim = Aer.get_backend('aer_simulator')
shots = 1024
# shots = 1000000 # max shots
qobj = assemble(circuit, aer_sim, shots=shots)
results = aer_sim.run(qobj).result()
answer = results.get_counts()

plot_histogram(answer)

# %% [raw]
# Run on real device:

# %%
# Load our saved IBMQ accounts and get the least busy backend device with greater than or equal to (n+1) qubits
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= (n) and
                                                         not x.configuration().simulator and x.status().operational==True))
print("least busy backend: ", backend)
# Out:
# least busy backend:  ibmq_armonk

# %%
# Run our circuit on the least busy backend. Monitor the execution of the job in the queue
from qiskit.tools.monitor import job_monitor

shots = 1024
transpiled_circuit = transpile(circuit, backend, optimization_level=0)
job = backend.run(transpiled_circuit)
job_monitor(job, interval=2)
# Out:
# Job Status: job has successfully run
